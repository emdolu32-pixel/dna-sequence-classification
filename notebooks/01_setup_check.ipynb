# %%
import sys, pandas as pd, numpy as np, sklearn, matplotlib, seaborn, Bio

print("Python:", sys.version.split()[0])
print("Running from:", sys.prefix)
for lib in (pd, np, sklearn, matplotlib, seaborn, Bio):
    print(f"{lib.__name__:12} {lib.__version__}")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Python: 3.13.5
# Running from: /Users/XPS/Desktop/projectFiles/dna-sequence-classification/.venv
# pandas       3.0.6
# numpy        2.5.3
# sklearn      1.9.1
# matplotlib   3.11.2
# seaborn      0.13.2
# Bio          1.88
